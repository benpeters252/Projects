# %% [markdown]
# ## YData Profiling: NASA Meteorites example
# Source of data: https://data.nasa.gov/docs/legacy/meteorite_landings/Meteorite_Landings.csv

# %% [markdown]
# The autoreload instruction reloads modules automatically before code execution, which is helpful for the update below.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Make sure that we have the latest version of pandas-profiling.

# %%
import sys

# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Collecting ydata-profiling[notebook]
#   Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.1.4)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook])
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.26.4)
# Collecting minify-html>=0.15.0 (from ydata-profiling[notebook])
#   Downloading minify_html-0.16.4-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling[notebook])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling[notebook])
#   Downloading phik-0.12.5-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling[notebook])
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.14.2)
# Collecting typeguard<5,>=3 (from ydata-profiling[notebook])
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling[notebook])
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling[notebook])
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling[notebook])
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.60.0)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\benpe\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (7.8.1)
# Requirement already satisfied: PyWavelets in c:\users\benpe\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.7.0)
# Requirement already satisfied: pillow in c:\users\benpe\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (10.4.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\benpe\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (2.1.3)
# Requirement already satisfied: notebook in c:\users\benpe\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.4)
# Requirement already satisfied: qtconsole in c:\users\benpe\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\benpe\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\benpe\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\benpe\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.28.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\benpe\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\benpe\anaconda3\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling[notebook]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\benpe\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\benpe\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\benpe\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\benpe\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\benpe\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\benpe\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\benpe\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\benpe\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\benpe\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\benpe\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\benpe\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (0.5.6)
# Requirement already satisfied: colorama in c:\users\benpe\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Collecting typing-extensions>=4.6.1 (from pydantic>=2->ydata-profiling[notebook])
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\benpe\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\benpe\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.3)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook])
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: decorator in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\benpe\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\benpe\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\benpe\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\benpe\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.4 in c:\users\benpe\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.4.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\benpe\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\benpe\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (6.4.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\benpe\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\benpe\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\benpe\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->ydata-profiling[notebook]) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\benpe\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\benpe\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\benpe\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\benpe\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\benpe\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\benpe\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.5)
# Requirement already satisfied: executing in c:\users\benpe\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\benpe\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\benpe\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\benpe\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\benpe\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\benpe\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\benpe\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\benpe\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\benpe\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\benpe\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\benpe\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook])
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook])
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\benpe\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook])
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook])
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\benpe\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\benpe\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\benpe\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.3)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.16.4-cp312-cp312-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 4.7 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp312-cp312-win_amd64.whl (676 kB)
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    ---------------------------------------- 676.2/676.2 kB 3.8 MB/s eta 0:00:00
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl (399 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: puremagic, minify-html, filetype, webcolors, uri-template, typing-extensions, multimethod, fqdn, dacite, typeguard, imagehash, wordcloud, visions, phik, isoduration, ydata-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
# Successfully installed dacite-1.9.2 filetype-1.2.0 fqdn-1.5.1 imagehash-4.3.1 isoduration-20.11.0 minify-html-0.16.4 multimethod-1.12 phik-0.12.5 puremagic-1.30 typeguard-4.4.4 typing-extensions-4.15.0 uri-template-1.3.0 visions-0.8.1 webcolors-24.11.1 wordcloud-1.9.4 ydata-profiling-4.17.0

# %% [markdown]
# You might want to restart the kernel now.

# %% [markdown]
# ### Import libraries

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import requests

import ydata_profiling
from ydata_profiling.utils.cache import cache_file
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ### Load and prepare example dataset
# We add some fake variables for illustrating pandas-profiling capabilities

# %%
file_name = cache_file(
    "meteorites.csv",
    "https://data.nasa.gov/docs/legacy/meteorite_landings/Meteorite_Landings.csv",
)

df = pd.read_csv(file_name)

# Note: Pandas does not support dates before 1880, so we ignore these for this analysis
df["year"] = pd.to_datetime(df["year"], errors="coerce")

# Example: Constant variable
df["source"] = "NASA"

# Example: Boolean variable
df["boolean"] = np.random.choice([True, False], df.shape[0])

# Example: Mixed with base types
df["mixed"] = np.random.choice([1, "A"], df.shape[0])

# Example: Highly correlated variables
df["reclat_city"] = df["reclat"] + np.random.normal(scale=5, size=(len(df)))

# Example: Duplicate observations
duplicates_to_add = pd.DataFrame(df.iloc[0:10])
duplicates_to_add["name"] = duplicates_to_add["name"] + " copy"

df = pd.concat([df, duplicates_to_add], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000002101D8C6750>, 'Connection to data.nasa.gov timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='data.nasa.gov', port=443): Max retries exceeded with url: /docs/legacy/meteorite_landings/Meteorite_Landings.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002101D8C6750>, 'Connection to data.nasa.gov timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 file_name = cache_file(
#       2     "meteorites.csv",
#       3     "https://data.nasa.gov/docs/legacy/meteorite_landings/Meteorite_Landings.csv",
#       4 )
#       6 df = pd.read_csv(file_name)
#       8 # Note: Pandas does not support dates before 1880, so we ignore these for this analysis
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\utils\cache.py:28, in cache_file(file_name, url)
#      26 # If not exists, download and create file
#      27 if not file_path.exists():
# ---> 28     response = get_file(url, allow_redirects=True)
#      29     response.raise_for_status()
#      31     file_path.write_bytes(response.content)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='data.nasa.gov', port=443): Max retries exceeded with url: /docs/legacy/meteorite_landings/Meteorite_Landings.csv (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002101D8C6750>, 'Connection to data.nasa.gov timed out. (connect timeout=None)'))

# %% [markdown]
# ### Inline report without saving object

# %%
report = df.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report

# %% [markdown]
# ### Save report to file

# %%
profile_report = df.profile_report(html={"style": {"full_width": True}})
profile_report.to_file("/tmp/example.html")

# %% [markdown]
# ### More analysis (Unicode) and Print existing ProfileReport object inline

# %%
profile_report = df.profile_report(
    explorative=True, html={"style": {"full_width": True}}
)
profile_report

# %% [markdown]
# ### Notebook Widgets

# %%
profile_report.to_widgets()
