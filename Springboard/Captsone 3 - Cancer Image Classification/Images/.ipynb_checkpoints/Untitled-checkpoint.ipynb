# %% [markdown]
# # Data Cleaning and EDA

# %% [markdown]
# Overall Project Goals:
# 1. Create a model that can take a jpeg of a histology slide
# 2. Determine if that slide ahs cancer or not (Cancer must be in the center of the image)
#
# Goals of this notebook are the following:
# 1. Confirm that the train, test, and validation image sets are all complete.
# 2.
